# %%
#sale predicting

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np
import pandas as pd

# %%
file = '/Users/sahilaggarwal/Downloads/sales_data_sample.csv'
encodings = ['utf-8', 'ISO-8859-1', 'cp1252']

for encoding in encodings:
    try:
        data = pd.read_csv(file, encoding=encoding)
        print(f"Successfully read the CSV file using encoding: {encoding}")
        break
    except UnicodeDecodeError:
        print(f"Error reading CSV file with encoding: {encoding}")
# Out:
# Error reading CSV file with encoding: utf-8
# Successfully read the CSV file using encoding: ISO-8859-1

# %%
data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
data.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
data.drop(columns=['ADDRESSLINE2','ADDRESSLINE1','ORDERDATE','STATUS','CITY','STATE','COUNTRY','TERRITORY','CONTACTLASTNAME','CONTACTFIRSTNAME','DEALSIZE','PRODUCTLINE','CUSTOMERNAME','PRODUCTCODE','PHONE','POSTALCODE'],inplace=True)

# %%
x=data.drop(columns=['SALES'])
y=data['SALES']

# %%
y.head()
# Out:
# 0    2871.00
# 1    2765.90
# 2    3884.34
# 3    3746.70
# 4    5205.27
# Name: SALES, dtype: float64

# %%
x.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  QTR_ID  MONTH_ID  \
# 0        10107               30      95.70                2       1         2
# 1        10121               34      81.35                5       2         5
# 2        10134               41      94.74                2       3         7
# 3        10145               45      83.26                6       3         8
# 4        10159               49     100.00               14       4        10
#
#    YEAR_ID  MSRP
# 0     2003    95
# 1     2003    95
# 2     2003    95
# 3     2003    95
# 4     2003    95

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=lr.predict(x_test)

# %%
pred
# Out:
# array([ 1.32605578e+03,  2.68773587e+03,  4.78869531e+03,  4.83906150e+03,
#         3.41441064e+03,  6.14892610e+03,  3.88856112e+03,  1.53926207e+03,
#         2.55750644e+03,  7.22642607e+03,  2.89843648e+03,  2.71983629e+03,
#        -8.99089912e+02,  4.80191204e+03,  5.37756265e+03,  5.27437674e+03,
#         1.25788776e+03,  5.88335342e+03,  2.01024355e+03, -1.01766985e+02,
#         5.28539435e+03,  3.63352126e+03,  6.94817236e+03,  1.03832005e+03,
#         8.02427222e+02,  5.46942617e+03, -6.55780217e+02,  5.33406216e+03,
#         2.94377621e+03,  2.92696321e+03,  3.96974516e+03,  4.71183579e+03,
#         3.53151883e+03,  2.61458300e+03,  4.62391335e+03, -4.16230751e+02,
#         1.75901595e+03,  2.43280123e+03,  3.12722142e+03,  5.04988934e+03,
#         5.72730574e+03,  3.64076195e+03,  3.88355265e+03,  1.26716513e+03,
#         3.76885426e+03,  3.96850470e+03,  4.43409279e+03,  4.27710983e+03,
# ...

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 1037690.1589838697
